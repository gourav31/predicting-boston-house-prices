# %%
import numpy as np

# %%
import pandas as pd

# %%
mydata=pd.read_csv(r"D:\DataSets-master\Housing data.csv")

# %%
mydata
# Out:
#      Unnamed: 0     price  lotsize  bedrooms  bathrms  stories driveway  \
# 0             1   42000.0     5850         3        1        2      yes
# 1             2   38500.0     4000         2        1        1      yes
# 2             3   49500.0     3060         3        1        1      yes
# 3             4   60500.0     6650         3        1        2      yes
# 4             5   61000.0     6360         2        1        1      yes
# 5             6   66000.0     4160         3        1        1      yes
# 6             7   66000.0     3880         3        2        2      yes
# 7             8   69000.0     4160         3        1        3      yes
# 8             9   83800.0     4800         3        1        1      yes
# 9            10   88500.0     5500         3        2        4      yes
# 10           11   90000.0     7200         3        2        1      yes
# 11           12   30500.0     3000         2        1        1       no
# ...

# %%
mydata.head(1)
# Out:
#    Unnamed: 0    price  lotsize  bedrooms  bathrms  stories driveway recroom  \
# 0           1  42000.0     5850         3        1        2      yes      no
#
#   fullbase gashw airco  garagepl prefarea
# 0      yes    no    no         1       no

# %%
x_data=mydata["lotsize"]

# %%
y_data=mydata["price"]

# %%
x_cr=x_data.values.reshape(len(x_data),1)

# %%
y_cr=y_data.values.reshape(len(y_data),1)

# %%
x_ntrain=x_cr[:-250]

# %%
x_ntrain.shape
# Out:
# (296, 1)

# %%
x_ntest=x_cr[-250:]

# %%
x_ntest.shape
# Out:
# (250, 1)

# %%
y_ntrain=y_cr[:-250]

# %%
y_ntest=y_cr[-250:]

# %%
y_ntrain.shape
# Out:
# (296, 1)

# %%
y_ntest.shape
# Out:
# (250, 1)

# %%
from sklearn.linear_model  import LinearRegression

# %%
myler=LinearRegression()

# %%
mymodel=myler.fit(x_ntrain,  y_ntrain)

# %%
ya=y_ntest

# %%
yp=mymodel.predict(x_ntest)

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(x_ntest, y_ntest,"*r")
plt.plot(x_ntest,yp)
plt.xlabel("lotsize")
plt.ylabel("price")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ys=mymodel.predict(6000)

# %%
ys
# Out:
# array([[67754.37706047]])

# %%
mymodel.intercept_
# Out:
# array([30963.20639361])

# %%
mymodel.coef_
# Out:
# array([[6.13186178]])

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_ntest,yp)
# Out:
# 19657.84496631826

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_ntest,yp)
# Out:
# 725949564.3930496
